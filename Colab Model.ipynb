# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
application_df.drop(["EIN"], axis = 1, inplace = True)

application_df.sample(10)
# Out:
#                                                     NAME APPLICATION_TYPE  \
# 24136  AMERICAN FEDERATION OF LABOR AND CONGRESS OF I...               T5
# 20081  UNIVERSITY OF KANSAS MEDICAL CENTER RESEARCH I...               T3
# 23680      SOROPTIMIST INTERNATIONAL OF THE AMERICAS INC               T3
# 18157                        WASHINGTON STATE UNIVERSITY               T3
# 14779            ABRAHAM LINCOLN ELEMENTARY BOOSTER CLUB               T3
# 16876    AMATEUR ATHLETIC UNION OF THE UNITED STATES INC               T3
# 33528  VETERANS OF FOREIGN WARS OF THE UNITED STATES ...              T19
# 12391                         MONTANA 4-H FOUNDATION INC               T3
# 29274                DEPARTMENT OF WYOMING VFW AUXILIARY              T19
# 3745          INTERNATIONAL ASSOCIATION OF FIRE FIGHTERS               T5
#
#             AFFILIATION CLASSIFICATION      USE_CASE ORGANIZATION  STATUS  \
# 24136  CompanySponsored          C3000    ProductDev  Association       1
# 20081       Independent          C1200  Preservation        Trust       1
# 23680  CompanySponsored          C1000  Preservation  Association       1
# 18157  CompanySponsored          C2000  Preservation        Trust       1
# 14779       Independent          C2000  Preservation        Trust       1
# 16876  CompanySponsored          C1200  Preservation        Trust       1
# 33528  CompanySponsored          C1000    ProductDev  Association       1
# 12391  CompanySponsored          C2000  Preservation        Trust       1
# 29274  CompanySponsored          C1000    ProductDev  Association       1
# 3745   CompanySponsored          C3000    ProductDev  Association       1
#
#         INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  IS_SUCCESSFUL
# 24136            0                      N      5000              1
# 20081         50M+                      N  69494994              0
# 23680  25000-99999                      N     59426              0
# 18157            0                      N      5000              0
# 14779            0                      N      5000              0
# 16876  25000-99999                      N      9330              0
# 33528            0                      N      5000              0
# 12391            0                      N      5000              0
# 29274            0                      N      5000              0
# 3745             0                      N      5000              1

# %%
application_types_to_replace = ["T9", "T13", "T12", "T2", "T25", "T14", "T29", "T15", "T17"]

for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
classification_counts = application_df["CLASSIFICATION"].value_counts()
classifications_to_replace = classification_counts[classification_counts < 778].index.tolist()

for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
application_df = pd.get_dummies(application_df)

# %%
y = application_df["IS_SUCCESSFUL"]
x = application_df.drop("IS_SUCCESSFUL", axis = 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 1)

# %%
scaler = StandardScaler()

x_scaler = scaler.fit(x_train)

x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %%
nn = tf.keras.models.Sequential()

nn.add(tf.keras.layers.Dense(units = 40, activation = "relu", input_dim = 34))

nn.add(tf.keras.layers.Dense(units = 30, activation = "tanh"))

nn.add(tf.keras.layers.Dense(units = 30, activation = "sigmoid"))

nn.add(tf.keras.layers.Dense(units = 1, activation = "sigmoid"))

nn.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
fit_model = nn.fit(x_train_scaled, y_train, epochs = 20)

# %%
model_loss, model_accuracy = nn.evaluate(x_test_scaled, y_test, verbose = 2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5548 - accuracy: 0.7292 - 468ms/epoch - 2ms/step
# Loss: 0.5547952055931091, Accuracy: 0.7292128205299377
